# %% [markdown]
# <a href="https://colab.research.google.com/github/sduarte09/chaotic-downscaling/blob/master/TensorFlow_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# Data

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# Model (1 layer - 1 neuron -1 value)

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Model (loss function and optimizer)

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# Train the neural network

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 573ms/step - loss: 44.5567
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 35.0572
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 27.5834
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 21.7033
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 17.0770
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 13.4373
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 10.5737
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3207
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.5482
# Epoch 10/500
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1536
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0563
# Epoch 12/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1930
# ...

# %% [markdown]
# Use Model

# %%
print(model.predict([10.0]))
# Out:
# [[31.001717]]
